# %% [markdown]
# <a href="https://colab.research.google.com/github/NallelyLizardi/proyectomcd/blob/main/Lizardi_proyectoMCD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nallely LIzardi Trabajo final.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pl

# %%
xls_IMM_url = "http://www.conapo.gob.mx/work/models/CONAPO/Marginacion/Datos_Abiertos/Municipio/IMM_2020.xls"
local_IMM_filename = "IMM_2020.xls"

df_IMM = pd.read_excel(xls_IMM_url, header=5)
df_IMM.head(7)
# Out:
#     CVE_ENT         NOM_ENT  CVE_MUN         NOM_MUN      POB_TOT     ANALF  \
# 0       NaN             NaN      NaN             NaN          NaN       NaN
# 1  Nacional             NaN      NaN             NaN  126014024.0  4.752150
# 2        01  Aguascalientes   1001.0  Aguascalientes     948990.0  1.644738
# 3        01  Aguascalientes   1002.0        Asientos      51536.0  3.526405
# 4        01  Aguascalientes   1003.0        Calvillo      58250.0  4.491509
# 5        01  Aguascalientes   1004.0           Cosío      17000.0  3.144867
# 6        01  Aguascalientes   1005.0     Jesús María     129929.0  2.380588
#
#        SBASC     OVSDE     OVSEE     OVSAE      OVPT       VHAC    PL.5000  \
# 0        NaN       NaN       NaN       NaN       NaN        NaN        NaN
# 1  29.713764  1.469115  0.660563  3.667182  3.807968  19.732297  26.999922
# 2  20.367220  0.104799  0.113169  0.378610  0.591434  10.339530   7.523683
# ...

# %%
df_IMM.describe()
# Out:
#             CVE_MUN       POB_TOT        ANALF        SBASC        OVSDE  \
# count   2469.000000  2.470000e+03  2470.000000  2470.000000  2470.000000
# mean   19324.164844  1.020356e+05    10.162275    45.846491     3.159278
# std     7382.892458  2.538770e+06     7.632863    13.982533     5.288337
# min     1001.000000  8.100000e+01     0.353446     5.535137     0.000000
# 25%    14079.000000  4.490000e+03     4.427779    35.726469     0.651985
# 50%    20226.000000  1.355650e+04     8.198294    46.339039     1.430479
# 75%    24027.000000  3.528775e+04    13.776450    55.845490     3.342595
# max    32058.000000  1.260140e+08    53.071253    88.328076    64.450424
#
#              OVSEE        OVSAE         OVPT         VHAC      PL.5000  \
# count  2470.000000  2470.000000  2470.000000  2470.000000  2470.000000
# mean      1.500453     6.117153     7.985540    26.563519    69.883100
# std       2.768658     9.244254     8.972167    10.585289    35.271147
# ...

# %%
df_mun_mar = df_IMM.groupby(['NOM_ENT', 'GM_2020']).size().unstack(fill_value=0)
df_mun_mar.head()
#porc = df_mun_mar.div(df_IMM.sum(axis=1), axis=0)
#porc.head()
#porc.plot.bar(stacked=True)
#pl.xlabel('Estado')
#pl.ylabel('Porcentaje')
#pl.title('Porcentaje de Municipios por Estado con Índices de Marginación')

#pl.savefig('grafica_marginacion.png')
# Out:
# GM_2020              Muy bajo  Medio  Alto  Bajo  Muy alto
# NOM_ENT
# Aguascalientes             11      0     0     0         0
# Baja California             5      1     0     0         0
# Baja California Sur         5      0     0     0         0
# Campeche                    2      2     2     6         0
# Chiapas                     1     30    66     7        20

# %%
df_IMM.drop(df_IMM[(df_IMM['CVE_ENT']=='NaN').index])
df_filtrado = df_IMM[df_IMM['POB_TOT'] < 5000]
df_IMM.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-82-58db7684cfe6> in <cell line: 1>()
# ----> 1 df_IMM.drop(df_IMM[(df_IMM['CVE_ENT']=='NaN').index])
#       2 df_filtrado = df_IMM[df_IMM['POB_TOT'] < 5000]
#       3 df_IMM.head()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3811             if is_iterator(key):
#    3812                 key = list(key)
# -> 3813             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3814
#    3815         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6068             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6069
# -> 6070         self._raise_if_missing(keyarr, indexer, axis_name)
#    6071
# ...
